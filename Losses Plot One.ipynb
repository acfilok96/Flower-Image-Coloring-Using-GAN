# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Losses Plot One.ipynb', 'PixToPixGAN_Loss_Record.npz']

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = np.load("PixToPixGAN_Loss_Record.npz")

# %%
real_loss = losses['a']
fake_loss = losses['b']
gan_loss = losses['c']
print(real_loss.shape)
print(fake_loss.shape)
print(gan_loss.shape)
# Out:
# (18000,)
# (18000,)
# (18000,)

# %%
plt.figure(figsize=(20,6))
plt.plot(real_loss)
plt.title("Real Loss",fontsize=40)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.plot(fake_loss)
plt.title("Fake Loss",fontsize=40)
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.plot(gan_loss)
plt.title("GAN Loss",fontsize=40)
plt.show()
